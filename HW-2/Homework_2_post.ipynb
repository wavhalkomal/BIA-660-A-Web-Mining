# %% [markdown]
# <h1><center>HW 2: Scrape Book Reviews</center></h1>

# %% [markdown]
# Choose one of your favorite book at goodreads.com (e.g. for the book "The Midninght Library", the URL is: https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true)

# %% [markdown]
# - Q1. Write a function to scrape all **reviews on the first page**, including,
#     - **reviewer's name** (see (1) in Figure)
#     - **number of reviews** (see (2) in Figure)
#     - **number of followers** (see (3) in Figure)
#     - **rating** (see (4) in Figure)
#     - **date** (see (5) in Figure)
#     - **review content** (see (6) in Figure. For each review text, need to get the **complete text**, i.e., need to expand the `more` button. Only text is needed, pictures are not needed. Hint: take a close look at the content of the html file.)
#     - If a field, e.g. score, is missing, use `None` to indicate it.
# - `Function Input`: book page URL
# - `Function Output`: save all reviews as a DataFrame of columns (`reviewer, number, follower, rating, date, review, like`). E.g., for the given URL, you can get 30 reviews.
#
# ![alt text](GoodReads2.png "GoodReads")

# %%
import requests
from bs4 import BeautifulSoup  
import pandas as pd


def getReviews(page_url):
    
   # enter your code

# %%
# enter your url
page_url = 'https://www.goodreads.com/book/show/52578297/reviews?reviewFilters='

reviews=getReviews(page_url)
reviews
# Out:
#                                        name            num         follower  \
# 0                                  Nataliya    882 reviews  14.6k followers
# 1                                       Yun    566 reviews  29.2k followers
# 2                                     Gabby  1,517 reviews  28.7k followers
# 3                                    Nicole    814 reviews  2,369 followers
# 4                             Miranda Reads  1,589 reviews   162k followers
# 5                                  Paromjit  3,050 reviews  25.6k followers
# 6                           Nilufer Ozmekik  2,663 reviews  53.7k followers
# 7                                      emma  2,237 reviews  73.6k followers
# 8                                 Emily May  2,086 reviews   314k followers
# 9                              Lisa of Troy    760 reviews  6,369 followers
# 10                        Reading_ Tamishly  5,154 reviews  3,168 followers
# 11                                    Jayme  1,340 reviews  3,417 followers
# 12                                 AdiTurbo    766 reviews     89 followers
# 13  Emily (Books with Emily Fox on Youtube)    601 reviews  66.6k followers
# 14                             Ruby Granger        Author           3 books
# 15              Hailey (Hailey in Bookland)    614 reviews  85.5k followers
# 16                                    Cindy    473 reviews   127k followers
# 17                                  Emily B    475 reviews    493 followers
# 18                           Claudia Lomelí        Author          10 books
# 19                             David Putnam        Author          19 books
# 20                              BlackOxford  1,095 reviews  69.3k followers
# 21            Dr. Appu Sasidharan (Dasfill)  1,358 reviews  3,390 followers
# 22                             Jenny Lawson        Author           6 books
# 23           Meredith (Trying to catch up!)    876 reviews  13.9k followers
# 24                                  Matthew  1,221 reviews  9,724 followers
# 25                              Ali Goodwin    256 reviews  34.1k followers
# 26                                 Danielle    997 reviews    583 followers
# 27                          Susan's Reviews  1,164 reviews    660 followers
# 28                                 Jaylynny    664 reviews      8 followers
# 29                                  jessica  2,590 reviews  44.8k followers
#
